# %%
import pandas as pd
import os

# %%
def modify_df(file_name):
    """
    A function that reads file in csv format which was exported by LabelStudio.
    This function will transform given csv into dataframe that is more suitable for our sound classification.
    :param file_name: the string object that represents file name
    :returns: pandas.DataFrame object that represents data from the csv turned into our style.
    """
    data = pd.read_csv(file_name)
    
    file_names = list()
    start = list()
    end = list()
    class_name = list()

    for i in range(len(data)):
        instance = data.loc[i]
        cur_file_name = os.path.join(os.getcwd(), instance['audio'][1:])
        cur_class = eval(instance['intent'])  # Each values are recorded as str, so need eval
        cur_time_lines = eval(data.loc[i]['labels'])

        for j in range(len(cur_class)):
            cur_start = float(cur_time_lines[j]['start'])
            cur_end = float(cur_time_lines[j]['end'])

            start.append(cur_start)
            end.append(cur_end)
            class_name.append(cur_class[j])
            file_names.append(cur_file_name)

    modified_df = pd.DataFrame()
    modified_df['file_name'] = file_names
    modified_df['start'] = start
    modified_df['end'] = end
    modified_df['class'] = class_name
    
    return modified_df

# %%
from PIL import Image
from pydub import AudioSegment
import sqlite3
import string
import os

def generate_db():
    """
    A function that generates training_data/data.db file and initializes the table values.
    :return: None
    """
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    conn.execute("CREATE TABLE data(data_name TEXT, data_count INTEGER)")
    
    default_data = [(x, 0) for x in string.ascii_lowercase]
    default_data = default_data + [(str(x), 0) for x in range(0, 10, 1)]
    default_data.append(("null", 0))
    
    cur.executemany("INSERT INTO data VALUES(?, ?)", default_data)
    
    conn.commit()
    conn.close()
    
def get_data_count(data_name):
    """
    A function that gets data count from data.db for specific data_name
    :param data_name: the data_name to look for data counts
    :return: returns count of data_count value for provided data_name, returns -1 if data_name does not exist.
    """
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    cur.execute("SELECT data_count FROM data WHERE data_name=\"" + data_name + "\"")
    rows = cur.fetchall()
    try:
        return rows[0][0]
    except IndexError:
        return -1
    
    conn.close()
    
def update_data_count(data_name):
    """
    A function that adds 1 to the current data_count for specified data_name
    :param data_name: the data_name to update values into
    :return: None
    """
    before_count = get_data_count(data_name)    
    new_count = before_count + 1
    
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    cur.execute("UPDATE data SET data_count=" + str(new_count) + " WHERE data_name=\"" + data_name + "\"")
    conn.commit()
    conn.close()

def generate_all_directories():
    """
    A function that generates training_data directories.
    This will generate trainig_data/a~z and 0~9 directories.
    :return: None
    """
    dir_names = [x for x in string.ascii_lowercase]
    dir_names = dir_names + [str(x) for x in range(0, 10, 1)]

    training_data_path = os.path.join(os.getcwd(), "training_data")

    if not os.path.exists(training_data_path):  # generate training_data directory
        os.mkdir(training_data_path)
    
    for i in dir_names:  # generate subdirectories such as a ~ z, 0 ~ 9
        new_dir= os.path.join(training_data_path, i)
        if not os.path.exists(new_dir):
            os.mkdir(new_dir)

def process_df(df):
    """
    A function that splits each sound classifications from dataframe into different files
    :param df: the pandas.DataFrame object that represents single row of information.
    """
    file_name = df['file_name']
    new_audio = AudioSegment.from_wav(file_name)
    
    start = df['start'] * 1000
    end = df['end'] * 1000
    class_name = df['class']
    
    tmp_audio = new_audio[start:end]
    
    save_dir = os.path.join(os.getcwd(), "training_data", class_name)
    new_file_name = str(get_data_count(class_name)) + ".wav"
    new_file_name = os.path.join(save_dir, new_file_name)
    update_data_count(class_name)
    tmp_audio.export(new_file_name, format="wav")

# %%
df = modify_df("project-3-at-2022-06-22-10-47-a1bccc9f.csv")

# %%
df
# Out:
#                                              file_name     start       end  \
# 0    /home/gooday2die/projects/Anti-Captcha/sounddo...  0.006369  0.630562
# 1    /home/gooday2die/projects/Anti-Captcha/sounddo...  1.082783  1.585958
# 2    /home/gooday2die/projects/Anti-Captcha/sounddo...  1.796146  2.337537
# 3    /home/gooday2die/projects/Anti-Captcha/sounddo...  2.872559  3.388473
# 4    /home/gooday2die/projects/Anti-Captcha/sounddo...  3.904388  4.350239
# ..                                                 ...       ...       ...
# 492  /home/gooday2die/projects/Anti-Captcha/sounddo...  0.019549  0.560398
# 493  /home/gooday2die/projects/Anti-Captcha/sounddo...  1.251121  1.883198
# 494  /home/gooday2die/projects/Anti-Captcha/sounddo...  2.515274  2.906250
# 495  /home/gooday2die/projects/Anti-Captcha/sounddo...  3.440583  3.948850
# 496  /home/gooday2die/projects/Anti-Captcha/sounddo...  4.378923  4.737317
#
#     class
# 0       y
# 1       r
# 2       9
# 3       k
# 4       c
# ..    ...
# 492     r
# 493     h
# 494     4
# 495     9
# 496     v
#
# [497 rows x 4 columns]

# %%
try:
    generate_db()
    print("[+] DB not found, generating a new one")
except sqlite3.OperationalError:  # when db already exists
    pass
generate_all_directories()

for i in range(len(df)):
    print("[+] Processing file " + str(i + 1) + " / " + str(len(df)))
    process_df(df.loc[i])
# Out:
# [+] DB not found, generating a new one
# [+] Processing file 0 / 497
# [+] Processing file 1 / 497
# [+] Processing file 2 / 497
# [+] Processing file 3 / 497
# [+] Processing file 4 / 497
# [+] Processing file 5 / 497
# [+] Processing file 6 / 497
# [+] Processing file 7 / 497
# [+] Processing file 8 / 497
# [+] Processing file 9 / 497
# [+] Processing file 10 / 497
# [+] Processing file 11 / 497
# [+] Processing file 12 / 497
# [+] Processing file 13 / 497
# [+] Processing file 14 / 497
# [+] Processing file 15 / 497
# [+] Processing file 16 / 497
# [+] Processing file 17 / 497
# [+] Processing file 18 / 497
# [+] Processing file 19 / 497
# [+] Processing file 20 / 497
# [+] Processing file 21 / 497
# [+] Processing file 22 / 497
# [+] Processing file 23 / 497
# [+] Processing file 24 / 497
# [+] Processing file 25 / 497
# [+] Processing file 26 / 497
# [+] Processing file 27 / 497
# [+] Processing file 28 / 497
# [+] Processing file 29 / 497
# [+] Processing file 30 / 497
# [+] Processing file 31 / 497
# [+] Processing file 32 / 497
# [+] Processing file 33 / 497
# [+] Processing file 34 / 497
# [+] Processing file 35 / 497
# [+] Processing file 36 / 497
# [+] Processing file 37 / 497
# [+] Processing file 38 / 497
# [+] Processing file 39 / 497
# [+] Processing file 40 / 497
# [+] Processing file 41 / 497
# [+] Processing file 42 / 497
# [+] Processing file 43 / 497
# [+] Processing file 44 / 497
# [+] Processing file 45 / 497
# [+] Processing file 46 / 497
# [+] Processing file 47 / 497
# [+] Processing file 48 / 497
# [+] Processing file 49 / 497
# [+] Processing file 50 / 497
# [+] Processing file 51 / 497
# [+] Processing file 52 / 497
# [+] Processing file 53 / 497
# [+] Processing file 54 / 497
# [+] Processing file 55 / 497
# [+] Processing file 56 / 497
# [+] Processing file 57 / 497
# [+] Processing file 58 / 497
# [+] Processing file 59 / 497
# [+] Processing file 60 / 497
# [+] Processing file 61 / 497
# [+] Processing file 62 / 497
# [+] Processing file 63 / 497
# [+] Processing file 64 / 497
# [+] Processing file 65 / 497
# [+] Processing file 66 / 497
# [+] Processing file 67 / 497
# [+] Processing file 68 / 497
# [+] Processing file 69 / 497
# [+] Processing file 70 / 497
# [+] Processing file 71 / 497
# [+] Processing file 72 / 497
# [+] Processing file 73 / 497
# [+] Processing file 74 / 497
# [+] Processing file 75 / 497
# [+] Processing file 76 / 497
# [+] Processing file 77 / 497
# [+] Processing file 78 / 497
# [+] Processing file 79 / 497
# [+] Processing file 80 / 497
# [+] Processing file 81 / 497
# [+] Processing file 82 / 497
# [+] Processing file 83 / 497
# [+] Processing file 84 / 497
# [+] Processing file 85 / 497
# [+] Processing file 86 / 497
# [+] Processing file 87 / 497
# [+] Processing file 88 / 497
# [+] Processing file 89 / 497
# [+] Processing file 90 / 497
# [+] Processing file 91 / 497
# [+] Processing file 92 / 497
# [+] Processing file 93 / 497
# [+] Processing file 94 / 497
# [+] Processing file 95 / 497
# [+] Processing file 96 / 497
# [+] Processing file 97 / 497
# [+] Processing file 98 / 497
# [+] Processing file 99 / 497
# [+] Processing file 100 / 497
# [+] Processing file 101 / 497
# [+] Processing file 102 / 497
# [+] Processing file 103 / 497
# [+] Processing file 104 / 497
# [+] Processing file 105 / 497
# [+] Processing file 106 / 497
# [+] Processing file 107 / 497
# [+] Processing file 108 / 497
# [+] Processing file 109 / 497
# [+] Processing file 110 / 497
# [+] Processing file 111 / 497
# [+] Processing file 112 / 497
# [+] Processing file 113 / 497
# [+] Processing file 114 / 497
# [+] Processing file 115 / 497
# [+] Processing file 116 / 497
# [+] Processing file 117 / 497
# [+] Processing file 118 / 497
# [+] Processing file 119 / 497
# [+] Processing file 120 / 497
# [+] Processing file 121 / 497
# [+] Processing file 122 / 497
# [+] Processing file 123 / 497
# [+] Processing file 124 / 497
# [+] Processing file 125 / 497
# [+] Processing file 126 / 497
# [+] Processing file 127 / 497
# [+] Processing file 128 / 497
# [+] Processing file 129 / 497
# [+] Processing file 130 / 497
# [+] Processing file 131 / 497
# [+] Processing file 132 / 497
# [+] Processing file 133 / 497
# [+] Processing file 134 / 497
# [+] Processing file 135 / 497
# [+] Processing file 136 / 497
# [+] Processing file 137 / 497
# [+] Processing file 138 / 497
# [+] Processing file 139 / 497
# [+] Processing file 140 / 497
# [+] Processing file 141 / 497
# [+] Processing file 142 / 497
# [+] Processing file 143 / 497
# [+] Processing file 144 / 497
# [+] Processing file 145 / 497
# [+] Processing file 146 / 497
# [+] Processing file 147 / 497
# [+] Processing file 148 / 497
# [+] Processing file 149 / 497
# [+] Processing file 150 / 497
# [+] Processing file 151 / 497
# [+] Processing file 152 / 497
# [+] Processing file 153 / 497
# [+] Processing file 154 / 497
# [+] Processing file 155 / 497
# [+] Processing file 156 / 497
# [+] Processing file 157 / 497
# [+] Processing file 158 / 497
# [+] Processing file 159 / 497
# [+] Processing file 160 / 497
# [+] Processing file 161 / 497
# [+] Processing file 162 / 497
# [+] Processing file 163 / 497
# [+] Processing file 164 / 497
# [+] Processing file 165 / 497
# [+] Processing file 166 / 497
# [+] Processing file 167 / 497
# [+] Processing file 168 / 497
# [+] Processing file 169 / 497
# [+] Processing file 170 / 497
# [+] Processing file 171 / 497
# [+] Processing file 172 / 497
# [+] Processing file 173 / 497
# [+] Processing file 174 / 497
# [+] Processing file 175 / 497
# [+] Processing file 176 / 497
# [+] Processing file 177 / 497
# [+] Processing file 178 / 497
# [+] Processing file 179 / 497
# [+] Processing file 180 / 497
# [+] Processing file 181 / 497
# [+] Processing file 182 / 497
# [+] Processing file 183 / 497
# [+] Processing file 184 / 497
# [+] Processing file 185 / 497
# [+] Processing file 186 / 497
# [+] Processing file 187 / 497
# [+] Processing file 188 / 497
# [+] Processing file 189 / 497
# [+] Processing file 190 / 497
# [+] Processing file 191 / 497
# [+] Processing file 192 / 497
# [+] Processing file 193 / 497
# [+] Processing file 194 / 497
# [+] Processing file 195 / 497
# [+] Processing file 196 / 497
# [+] Processing file 197 / 497
# [+] Processing file 198 / 497
# [+] Processing file 199 / 497
# [+] Processing file 200 / 497
# [+] Processing file 201 / 497
# [+] Processing file 202 / 497
# [+] Processing file 203 / 497
# [+] Processing file 204 / 497
# [+] Processing file 205 / 497
# [+] Processing file 206 / 497
# [+] Processing file 207 / 497
# [+] Processing file 208 / 497
# [+] Processing file 209 / 497
# [+] Processing file 210 / 497
# [+] Processing file 211 / 497
# [+] Processing file 212 / 497
# [+] Processing file 213 / 497
# [+] Processing file 214 / 497
# [+] Processing file 215 / 497
# [+] Processing file 216 / 497
# [+] Processing file 217 / 497
# [+] Processing file 218 / 497
# [+] Processing file 219 / 497
# [+] Processing file 220 / 497
# [+] Processing file 221 / 497
# [+] Processing file 222 / 497
# [+] Processing file 223 / 497
# [+] Processing file 224 / 497
# [+] Processing file 225 / 497
# [+] Processing file 226 / 497
# [+] Processing file 227 / 497
# [+] Processing file 228 / 497
# [+] Processing file 229 / 497
# [+] Processing file 230 / 497
# [+] Processing file 231 / 497
# [+] Processing file 232 / 497
# [+] Processing file 233 / 497
# [+] Processing file 234 / 497
# [+] Processing file 235 / 497
# [+] Processing file 236 / 497
# [+] Processing file 237 / 497
# [+] Processing file 238 / 497
# [+] Processing file 239 / 497
# [+] Processing file 240 / 497
# [+] Processing file 241 / 497
# [+] Processing file 242 / 497
# [+] Processing file 243 / 497
# [+] Processing file 244 / 497
# [+] Processing file 245 / 497
# [+] Processing file 246 / 497
# [+] Processing file 247 / 497
# [+] Processing file 248 / 497
# [+] Processing file 249 / 497
# [+] Processing file 250 / 497
# [+] Processing file 251 / 497
# [+] Processing file 252 / 497
# [+] Processing file 253 / 497
# [+] Processing file 254 / 497
# [+] Processing file 255 / 497
# [+] Processing file 256 / 497
# [+] Processing file 257 / 497
# [+] Processing file 258 / 497
# [+] Processing file 259 / 497
# [+] Processing file 260 / 497
# [+] Processing file 261 / 497
# [+] Processing file 262 / 497
# [+] Processing file 263 / 497
# [+] Processing file 264 / 497
# [+] Processing file 265 / 497
# [+] Processing file 266 / 497
# [+] Processing file 267 / 497
# [+] Processing file 268 / 497
# [+] Processing file 269 / 497
# [+] Processing file 270 / 497
# [+] Processing file 271 / 497
# [+] Processing file 272 / 497
# [+] Processing file 273 / 497
# [+] Processing file 274 / 497
# [+] Processing file 275 / 497
# [+] Processing file 276 / 497
# [+] Processing file 277 / 497
# [+] Processing file 278 / 497
# [+] Processing file 279 / 497
# [+] Processing file 280 / 497
# [+] Processing file 281 / 497
# [+] Processing file 282 / 497
# [+] Processing file 283 / 497
# [+] Processing file 284 / 497
# [+] Processing file 285 / 497
# [+] Processing file 286 / 497
# [+] Processing file 287 / 497
# [+] Processing file 288 / 497
# [+] Processing file 289 / 497
# [+] Processing file 290 / 497
# [+] Processing file 291 / 497
# [+] Processing file 292 / 497
# [+] Processing file 293 / 497
# [+] Processing file 294 / 497
# [+] Processing file 295 / 497
# [+] Processing file 296 / 497
# [+] Processing file 297 / 497
# [+] Processing file 298 / 497
# [+] Processing file 299 / 497
# [+] Processing file 300 / 497
# [+] Processing file 301 / 497
# [+] Processing file 302 / 497
# [+] Processing file 303 / 497
# [+] Processing file 304 / 497
# [+] Processing file 305 / 497
# [+] Processing file 306 / 497
# [+] Processing file 307 / 497
# [+] Processing file 308 / 497
# [+] Processing file 309 / 497
# [+] Processing file 310 / 497
# [+] Processing file 311 / 497
# [+] Processing file 312 / 497
# [+] Processing file 313 / 497
# [+] Processing file 314 / 497
# [+] Processing file 315 / 497
# [+] Processing file 316 / 497
# [+] Processing file 317 / 497
# [+] Processing file 318 / 497
# [+] Processing file 319 / 497
# [+] Processing file 320 / 497
# [+] Processing file 321 / 497
# [+] Processing file 322 / 497
# [+] Processing file 323 / 497
# [+] Processing file 324 / 497
# [+] Processing file 325 / 497
# [+] Processing file 326 / 497
# [+] Processing file 327 / 497
# [+] Processing file 328 / 497
# [+] Processing file 329 / 497
# [+] Processing file 330 / 497
# [+] Processing file 331 / 497
# [+] Processing file 332 / 497
# [+] Processing file 333 / 497
# [+] Processing file 334 / 497
# [+] Processing file 335 / 497
# [+] Processing file 336 / 497
# [+] Processing file 337 / 497
# [+] Processing file 338 / 497
# [+] Processing file 339 / 497
# [+] Processing file 340 / 497
# [+] Processing file 341 / 497
# [+] Processing file 342 / 497
# [+] Processing file 343 / 497
# [+] Processing file 344 / 497
# [+] Processing file 345 / 497
# [+] Processing file 346 / 497
# [+] Processing file 347 / 497
# [+] Processing file 348 / 497
# [+] Processing file 349 / 497
# [+] Processing file 350 / 497
# [+] Processing file 351 / 497
# [+] Processing file 352 / 497
# [+] Processing file 353 / 497
# [+] Processing file 354 / 497
# [+] Processing file 355 / 497
# [+] Processing file 356 / 497
# [+] Processing file 357 / 497
# [+] Processing file 358 / 497
# [+] Processing file 359 / 497
# [+] Processing file 360 / 497
# [+] Processing file 361 / 497
# [+] Processing file 362 / 497
# [+] Processing file 363 / 497
# [+] Processing file 364 / 497
# [+] Processing file 365 / 497
# [+] Processing file 366 / 497
# [+] Processing file 367 / 497
# [+] Processing file 368 / 497
# [+] Processing file 369 / 497
# [+] Processing file 370 / 497
# [+] Processing file 371 / 497
# [+] Processing file 372 / 497
# [+] Processing file 373 / 497
# [+] Processing file 374 / 497
# [+] Processing file 375 / 497
# [+] Processing file 376 / 497
# [+] Processing file 377 / 497
# [+] Processing file 378 / 497
# [+] Processing file 379 / 497
# [+] Processing file 380 / 497
# [+] Processing file 381 / 497
# [+] Processing file 382 / 497
# [+] Processing file 383 / 497
# [+] Processing file 384 / 497
# [+] Processing file 385 / 497
# [+] Processing file 386 / 497
# [+] Processing file 387 / 497
# [+] Processing file 388 / 497
# [+] Processing file 389 / 497
# [+] Processing file 390 / 497
# [+] Processing file 391 / 497
# [+] Processing file 392 / 497
# [+] Processing file 393 / 497
# [+] Processing file 394 / 497
# [+] Processing file 395 / 497
# [+] Processing file 396 / 497
# [+] Processing file 397 / 497
# [+] Processing file 398 / 497
# [+] Processing file 399 / 497
# [+] Processing file 400 / 497
# [+] Processing file 401 / 497
# [+] Processing file 402 / 497
# [+] Processing file 403 / 497
# [+] Processing file 404 / 497
# [+] Processing file 405 / 497
# [+] Processing file 406 / 497
# [+] Processing file 407 / 497
# [+] Processing file 408 / 497
# [+] Processing file 409 / 497
# [+] Processing file 410 / 497
# [+] Processing file 411 / 497
# [+] Processing file 412 / 497
# [+] Processing file 413 / 497
# [+] Processing file 414 / 497
# [+] Processing file 415 / 497
# [+] Processing file 416 / 497
# [+] Processing file 417 / 497
# [+] Processing file 418 / 497
# [+] Processing file 419 / 497
# [+] Processing file 420 / 497
# [+] Processing file 421 / 497
# [+] Processing file 422 / 497
# [+] Processing file 423 / 497
# [+] Processing file 424 / 497
# [+] Processing file 425 / 497
# [+] Processing file 426 / 497
# [+] Processing file 427 / 497
# [+] Processing file 428 / 497
# [+] Processing file 429 / 497
# [+] Processing file 430 / 497
# [+] Processing file 431 / 497
# [+] Processing file 432 / 497
# [+] Processing file 433 / 497
# [+] Processing file 434 / 497
# [+] Processing file 435 / 497
# [+] Processing file 436 / 497
# [+] Processing file 437 / 497
# [+] Processing file 438 / 497
# [+] Processing file 439 / 497
# [+] Processing file 440 / 497
# [+] Processing file 441 / 497
# [+] Processing file 442 / 497
# [+] Processing file 443 / 497
# [+] Processing file 444 / 497
# [+] Processing file 445 / 497
# [+] Processing file 446 / 497
# [+] Processing file 447 / 497
# [+] Processing file 448 / 497
# [+] Processing file 449 / 497
# [+] Processing file 450 / 497
# [+] Processing file 451 / 497
# [+] Processing file 452 / 497
# [+] Processing file 453 / 497
# [+] Processing file 454 / 497
# [+] Processing file 455 / 497
# [+] Processing file 456 / 497
# [+] Processing file 457 / 497
# [+] Processing file 458 / 497
# [+] Processing file 459 / 497
# [+] Processing file 460 / 497
# [+] Processing file 461 / 497
# [+] Processing file 462 / 497
# [+] Processing file 463 / 497
# [+] Processing file 464 / 497
# [+] Processing file 465 / 497
# [+] Processing file 466 / 497
# [+] Processing file 467 / 497
# [+] Processing file 468 / 497
# [+] Processing file 469 / 497
# [+] Processing file 470 / 497
# [+] Processing file 471 / 497
# [+] Processing file 472 / 497
# [+] Processing file 473 / 497
# [+] Processing file 474 / 497
# [+] Processing file 475 / 497
# [+] Processing file 476 / 497
# [+] Processing file 477 / 497
# [+] Processing file 478 / 497
# [+] Processing file 479 / 497
# [+] Processing file 480 / 497
# [+] Processing file 481 / 497
# [+] Processing file 482 / 497
# [+] Processing file 483 / 497
# [+] Processing file 484 / 497
# [+] Processing file 485 / 497
# [+] Processing file 486 / 497
# [+] Processing file 487 / 497
# [+] Processing file 488 / 497
# [+] Processing file 489 / 497
# [+] Processing file 490 / 497
# [+] Processing file 491 / 497
# [+] Processing file 492 / 497
# [+] Processing file 493 / 497
# [+] Processing file 494 / 497
# [+] Processing file 495 / 497
# [+] Processing file 496 / 497

# %%
from IPython.display import Audio 
Audio("/home/gooday2die/projects/Anti-Captcha/sounddooo/sounds/training_data/j/0.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
